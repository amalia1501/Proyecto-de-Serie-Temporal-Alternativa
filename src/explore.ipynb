# %% [markdown]
# # Explore here

# %%
# Your code here

import pandas as pd
import datetime as dt
from datetime import date

data = pd.read_csv("https://raw.githubusercontent.com/4GeeksAcademy/alternative-time-series-project/main/sales.csv")

data.head()
# Out:
#                          date      sales
# 0  2022-09-03 17:10:08.079328  55.292157
# 1  2022-09-04 17:10:08.079328  53.803211
# 2  2022-09-05 17:10:08.079328  58.141693
# 3  2022-09-06 17:10:08.079328  64.530899
# 4  2022-09-07 17:10:08.079328  66.013633

# %%
data.shape
# Out:
# (366, 2)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    366 non-null    object
#  1   sales   366 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 5.8+ KB

# %%
# Paso 2: Construye y analiza la serie temporal

import pandas as pd


data["date"] = pd.to_datetime(data.date)
data = data.set_index("date")
ts = data["sales"]
ts.head()
# Out:
# date
# 2022-09-03 17:10:08.079328    55.292157
# 2022-09-04 17:10:08.079328    53.803211
# 2022-09-05 17:10:08.079328    58.141693
# 2022-09-06 17:10:08.079328    64.530899
# 2022-09-07 17:10:08.079328    66.013633
# Name: sales, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, axis = plt.subplots(figsize = (10, 5))

sns.lineplot(data = ts)

plt.tight_layout()

plt.show()

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

decomposition = seasonal_decompose(ts, period = 12)
decomposition

# %%
# Análisis de la tendencia
trend = decomposition.trend

fig, axis = plt.subplots(figsize = (10, 5))

sns.lineplot(data = ts)
sns.lineplot(data = trend)

plt.tight_layout()

plt.show()

# %% [markdown]
# Tiene tendencia a la alta

# %%
# Análisis de la estacionalidad

seasonal = decomposition.seasonal

fig, axis = plt.subplots(figsize = (10, 5))

sns.lineplot(data = ts)
sns.lineplot(data = seasonal)

plt.tight_layout()

plt.show()

# %% [markdown]
# Segun el grafico no es estacional pero se aplica la prueba para corroborar esto.

# %%
from statsmodels.tsa.stattools import adfuller

def test_stationarity(timeseries):
    print("Resultados de la prueba de Dickey-Fuller:")
    dftest = adfuller(timeseries, autolag = "AIC")
    dfoutput = pd.Series(dftest[0:4], index = ["Test Statistic", "p-value", "#Lags Used", "Number of Observations Used"])
    for key,value in dftest[4].items():
        dfoutput["Critical Value (%s)"%key] = value
    return dfoutput

test_stationarity(ts)
# Out:
# Resultados de la prueba de Dickey-Fuller:
# Test Statistic                   0.545414
# p-value                          0.986190
# #Lags Used                      13.000000
# Number of Observations Used    352.000000
# Critical Value (1%)             -3.449065
# Critical Value (5%)             -2.869786
# Critical Value (10%)            -2.571163
# dtype: float64

# %% [markdown]
# Aquí podemos ver que el p-value es mayor a 0.05, esto significa que nuestra hipótesis nula será rechazada y tomaremos esta serie como no estacionaria.

# %%
# Análisis de la variabilidad

residual = decomposition.resid

fig, axis = plt.subplots(figsize = (10, 5))

sns.lineplot(data = ts)
sns.lineplot(data = residual)

plt.tight_layout()

plt.show()

# %% [markdown]
# La carga de residuos se hace más notable al inicio y al final del periodo estudiado.

# %%
# Análisis de la autocorrelación

from statsmodels.graphics.tsaplots import plot_acf

plot_acf(ts)

plt.tight_layout()

plt.show()

# %% [markdown]
# Se aprecia una alta correlación entre los puntos y sus copias retrasadas, que disminuye a lo largo del tiempo.

# %%
# Paso 3: Entrenamiento del modelo ARIMA

ts_stationary = ts.diff().dropna()

test_stationarity(ts_stationary)
# Out:
# Resultados de la prueba de Dickey-Fuller:
# Test Statistic                -9.430263e+00
# p-value                        5.212954e-16
# #Lags Used                     1.200000e+01
# Number of Observations Used    3.520000e+02
# Critical Value (1%)           -3.449065e+00
# Critical Value (5%)           -2.869786e+00
# Critical Value (10%)          -2.571163e+00
# dtype: float64

# %%
# %pip install pmdarima
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from pmdarima import auto_arima

# model = auto_arima(ts, seasonal = True, trace = True, m = 7)

# model = auto_arima(ts_stationary, seasonal = True, trace = True, m = 352)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from pmdarima import auto_arima
#       3 # model = auto_arima(ts, seasonal = True, trace = True, m = 7)
#       4
#       5 # model = auto_arima(ts_stationary, seasonal = True, trace = True, m = 352)
#
# File ~/.pyenv/versions/3.12.4/lib/python3.12/site-packages/pmdarima/__init__.py:52
#      49 from . import __check_build
#      51 # Stuff we want at top-level
# ---> 52 from .arima import auto_arima, ARIMA, AutoARIMA, StepwiseContext, decompose
#      53 from .utils import acf, autocorr_plot, c, pacf, plot_acf, plot_pacf, \
#      54     tsdisplay
#      55 from .utils._show_versions import show_versions
#
# File ~/.pyenv/versions/3.12.4/lib/python3.12/site-packages/pmdarima/arima/__init__.py:5
#       1 # -*- coding: utf-8 -*-
#       2 #
# ...

# %%
# Paso 4: Predice con el conjunto de test

forecast = model.predict(10)
forecast
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 3
#       1 # Paso 4: Predice con el conjunto de test
# ----> 3 forecast = model.predict(10)
#       4 forecast
#
# NameError: name 'model' is not defined

# %%
import matplotlib.pyplot as plt

fig, axis = plt.subplots(figsize = (10, 5))

sns.lineplot(data = ts_stationary)
sns.lineplot(data = forecast, c = "green")

plt.tight_layout()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 6
#       3 fig, axis = plt.subplots(figsize = (10, 5))
#       5 sns.lineplot(data = ts_stationary)
# ----> 6 sns.lineplot(data = forecast, c = "green")
#       8 plt.tight_layout()
#      10 plt.show()
#
# NameError: name 'forecast' is not defined

# %%
# Paso 5: Guarda el modelo
