# %% [markdown]
# # Explore here

# %%
# Your code here

import pandas as pd
import datetime as dt
from datetime import date

data = pd.read_csv("https://raw.githubusercontent.com/4GeeksAcademy/alternative-time-series-project/main/sales.csv")

data.head()
# Out:
#                          date      sales
# 0  2022-09-03 17:10:08.079328  55.292157
# 1  2022-09-04 17:10:08.079328  53.803211
# 2  2022-09-05 17:10:08.079328  58.141693
# 3  2022-09-06 17:10:08.079328  64.530899
# 4  2022-09-07 17:10:08.079328  66.013633

# %%
data.shape
# Out:
# (366, 2)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    366 non-null    object
#  1   sales   366 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 5.8+ KB

# %%
# Paso 2: Construye y analiza la serie temporal

import pandas as pd

# data["date"] = pd.to_datetime(data.date, format = "%Y-%m-%d").dt
# data["date"] = pd.to_datetime(data(format='%Y-%m-%d'))
data = data.set_index("date")
ts = data["sales"]
ts.head()
# Out:
# date
# 2022-09-03 17:10:08.079328    55.292157
# 2022-09-04 17:10:08.079328    53.803211
# 2022-09-05 17:10:08.079328    58.141693
# 2022-09-06 17:10:08.079328    64.530899
# 2022-09-07 17:10:08.079328    66.013633
# Name: sales, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, axis = plt.subplots(figsize = (10, 5))

sns.lineplot(data = ts)

plt.tight_layout()

plt.show()

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

decomposition = seasonal_decompose(ts, period = 12)
decomposition

# %%
trend = decomposition.trend

fig, axis = plt.subplots(figsize = (10, 5))

sns.lineplot(data = ts)
sns.lineplot(data = trend)

plt.tight_layout()

plt.show()

# %%
# Análisis de la tendencia

seasonal = decomposition.seasonal

fig, axis = plt.subplots(figsize = (10, 5))

sns.lineplot(data = ts)
sns.lineplot(data = seasonal)

plt.tight_layout()

plt.show()

# %%
# Análisis de la estacionalidad

seasonal = decomposition.seasonal

fig, axis = plt.subplots(figsize = (10, 5))

sns.lineplot(data = ts)
sns.lineplot(data = seasonal)

plt.tight_layout()

plt.show()

# %%
from statsmodels.tsa.stattools import adfuller

def test_stationarity(timeseries):
    print("Resultados de la prueba de Dickey-Fuller:")
    dftest = adfuller(timeseries, autolag = "AIC")
    dfoutput = pd.Series(dftest[0:4], index = ["Test Statistic", "p-value", "#Lags Used", "Number of Observations Used"])
    for key,value in dftest[4].items():
        dfoutput["Critical Value (%s)"%key] = value
    return dfoutput

test_stationarity(ts)
# Out:
# Resultados de la prueba de Dickey-Fuller:
# Test Statistic                   0.545414
# p-value                          0.986190
# #Lags Used                      13.000000
# Number of Observations Used    352.000000
# Critical Value (1%)             -3.449065
# Critical Value (5%)             -2.869786
# Critical Value (10%)            -2.571163
# dtype: float64

# %%
# Análisis de la variabilidad

residual = decomposition.resid

fig, axis = plt.subplots(figsize = (10, 5))

sns.lineplot(data = ts)
sns.lineplot(data = residual)

plt.tight_layout()

plt.show()

# %%
# Análisis de la autocorrelación

from statsmodels.graphics.tsaplots import plot_acf

plot_acf(ts)

plt.tight_layout()

plt.show()

# %%
# Paso 3: Entrenamiento del modelo

ts_stationary = ts.diff().dropna()

test_stationarity(ts_stationary)
# Out:
# Resultados de la prueba de Dickey-Fuller:
# Test Statistic                -9.430263e+00
# p-value                        5.212954e-16
# #Lags Used                     1.200000e+01
# Number of Observations Used    3.520000e+02
# Critical Value (1%)           -3.449065e+00
# Critical Value (5%)           -2.869786e+00
# Critical Value (10%)          -2.571163e+00
# dtype: float64

# %%
# %pip install pmdarima
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pmdarima in /home/vscode/.local/lib/python3.10/site-packages (2.0.4)
# Requirement already satisfied: joblib>=0.11 in /home/vscode/.local/lib/python3.10/site-packages (from pmdarima) (1.4.2)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /home/vscode/.local/lib/python3.10/site-packages (from pmdarima) (3.0.10)
# Requirement already satisfied: numpy>=1.21.2 in /home/vscode/.local/lib/python3.10/site-packages (from pmdarima) (2.0.0)
# Requirement already satisfied: pandas>=0.19 in /home/vscode/.local/lib/python3.10/site-packages (from pmdarima) (2.2.2)
# Requirement already satisfied: scikit-learn>=0.22 in /home/vscode/.local/lib/python3.10/site-packages (from pmdarima) (1.5.1)
# Requirement already satisfied: scipy>=1.3.2 in /home/vscode/.local/lib/python3.10/site-packages (from pmdarima) (1.14.0)
# Requirement already satisfied: statsmodels>=0.13.2 in /home/vscode/.local/lib/python3.10/site-packages (from pmdarima) (0.14.2)
# Requirement already satisfied: urllib3 in /home/vscode/.local/lib/python3.10/site-packages (from pmdarima) (2.2.2)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /usr/local/lib/python3.10/site-packages (from pmdarima) (67.8.0)
# Requirement already satisfied: packaging>=17.1 in /home/vscode/.local/lib/python3.10/site-packages (from pmdarima) (24.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/vscode/.local/lib/python3.10/site-packages (from pandas>=0.19->pmdarima) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/vscode/.local/lib/python3.10/site-packages (from pandas>=0.19->pmdarima) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/vscode/.local/lib/python3.10/site-packages (from pandas>=0.19->pmdarima) (2024.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/vscode/.local/lib/python3.10/site-packages (from scikit-learn>=0.22->pmdarima) (3.5.0)
# Requirement already satisfied: patsy>=0.5.6 in /home/vscode/.local/lib/python3.10/site-packages (from statsmodels>=0.13.2->pmdarima) (0.5.6)
# Requirement already satisfied: six in /home/vscode/.local/lib/python3.10/site-packages (from patsy>=0.5.6->statsmodels>=0.13.2->pmdarima) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from pmdarima import auto_arima

model = auto_arima(ts_stationary, seasonal = True, trace = True, m = 12)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 from pmdarima import auto_arima
#       3 model = auto_arima(ts_stationary, seasonal = True, trace = True, m = 12)
#
# File ~/.local/lib/python3.10/site-packages/pmdarima/__init__.py:52
#      49 from . import __check_build
#      51 # Stuff we want at top-level
# ---> 52 from .arima import auto_arima, ARIMA, AutoARIMA, StepwiseContext, decompose
#      53 from .utils import acf, autocorr_plot, c, pacf, plot_acf, plot_pacf, \
#      54     tsdisplay
#      55 from .utils._show_versions import show_versions
#
# File ~/.local/lib/python3.10/site-packages/pmdarima/arima/__init__.py:5
#       1 # -*- coding: utf-8 -*-
#       2 #
#       3 # Author: Taylor Smith <taylor.smith@alkaline-ml.com>
# ----> 5 from .approx import *
#       6 from .arima import *
#       7 from .auto import *
#
# File ~/.local/lib/python3.10/site-packages/pmdarima/arima/approx.py:9
#       1 # -*- coding: utf-8 -*-
#       2 #
#       3 # Author: Taylor Smith <taylor.smith@alkaline-ml.com>
#       4 #
#       5 # R approx function
#       7 import numpy as np
# ----> 9 from ..utils.array import c, check_endog
#      10 from ..utils import get_callable
#      11 from ..compat.numpy import DTYPE
#
# File ~/.local/lib/python3.10/site-packages/pmdarima/utils/__init__.py:5
#       1 # -*- coding: utf-8 -*-
#       2 #
#       3 # Author: Taylor Smith <taylor.smith@alkaline-ml.com>
# ----> 5 from .array import *
#       6 from .metaestimators import *
#       7 from .visualization import *
#
# File ~/.local/lib/python3.10/site-packages/pmdarima/utils/array.py:13
#      10 import pandas as pd
#      12 from ..compat import DTYPE
# ---> 13 from ._array import C_intgrt_vec
#      15 __all__ = [
#      16     'as_series',
#      17     'c',
#    (...)
#      22     'is_iterable'
#      23 ]
#      26 def as_series(x, **kwargs):
#
# File pmdarima/utils/_array.pyx:1, in init pmdarima.utils._array()
#
# ValueError: numpy.dtype size changed, may indicate binary incompatibility. Expected 96 from C header, got 88 from PyObject
